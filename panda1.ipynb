# %%
import pandas as pd

# %%
df = pd.DataFrame( {
    "date" : ["5/12/2025" , "6/12/2025"],
    "amount" : [500,600],
    "category" : ["badapav", "aato"]
})
print(df)
# Out:
#         date  amount category
# 0  5/12/2025     500  badapav
# 1  6/12/2025     600     aato

# %%
new_exp =  pd.DataFrame ({
    "date" : ["7/12/2025"],
    "amount" : [10000],
    "category" :[ "g lab"]
})

# %%
print(pd.concat([df,new_exp] , ignore_index= True))
total_expense = pd.concat([df,new_exp], ignore_index=True)
# Out:
#         date  amount category
# 0  5/12/2025     500  badapav
# 1  6/12/2025     600     aato
# 2  7/12/2025   10000    g lab

# %%
print(total_expense["amount"].sum())
# Out:
# 11100

# %%
print(total_expense["amount"].sum())
# Out:
# 11100

# %%
print(total_expense["category"]);print(df.loc[1,"amount"])
# Out:
# 0    badapav
# 1       aato
# 2      g lab
# Name: category, dtype: object
# 600

# %%
student_data = pd.read_csv('./students.csv')
print(student_data)
# Out:
#      STUDENT ID  Student Age  Sex  Graduated high-school type  \
# 0      STUDENT1            2    2                           3
# 1      STUDENT2            2    2                           3
# 2      STUDENT3            2    2                           2
# 3      STUDENT4            1    1                           1
# 4      STUDENT5            2    2                           1
# ..          ...          ...  ...                         ...
# 140  STUDENT141            2    1                           2
# 141  STUDENT142            1    1                           2
# 142  STUDENT143            1    1                           1
# 143  STUDENT144            2    1                           2
# 144  STUDENT145            1    1                           1
#
#      Scholarship type  Additional work  Regular artistic or sports activity  \
# 0                   3                1                                    2
# ...

# %%
print(student_data.head())
# Out:
#   STUDENT ID  Student Age  Sex  Graduated high-school type  Scholarship type  \
# 0   STUDENT1            2    2                           3                 3
# 1   STUDENT2            2    2                           3                 3
# 2   STUDENT3            2    2                           2                 3
# 3   STUDENT4            1    1                           1                 3
# 4   STUDENT5            2    2                           1                 3
#
#    Additional work  Regular artistic or sports activity  \
# 0                1                                    2
# 1                1                                    2
# 2                2                                    2
# 3                1                                    2
# 4                2                                    2
#
#    Do you have a partner  Total salary if available  \
# 0                      2                          1
# 1                      2                          1
# ...

# %%
print(student_data.tail())
# Out:
#      STUDENT ID  Student Age  Sex  Graduated high-school type  \
# 140  STUDENT141            2    1                           2
# 141  STUDENT142            1    1                           2
# 142  STUDENT143            1    1                           1
# 143  STUDENT144            2    1                           2
# 144  STUDENT145            1    1                           1
#
#      Scholarship type  Additional work  Regular artistic or sports activity  \
# 140                 3                1                                    1
# 141                 4                2                                    2
# 142                 4                2                                    2
# 143                 4                1                                    1
# 144                 5                2                                    2
#
#      Do you have a partner  Total salary if available  \
# 140                      2                          1
# ...

# %%
print(student_data.describe())
# Out:
#        Student Age         Sex  Graduated high-school type  Scholarship type  \
# count   145.000000  145.000000                  145.000000        145.000000
# mean      1.620690    1.600000                    1.944828          3.572414
# std       0.613154    0.491596                    0.537216          0.805750
# min       1.000000    1.000000                    1.000000          1.000000
# 25%       1.000000    1.000000                    2.000000          3.000000
# 50%       2.000000    2.000000                    2.000000          3.000000
# 75%       2.000000    2.000000                    2.000000          4.000000
# max       3.000000    2.000000                    3.000000          5.000000
#
#        Additional work  Regular artistic or sports activity  \
# count       145.000000                           145.000000
# mean          1.662069                             1.600000
# std           0.474644                             0.491596
# ...

# %%
print(student_data["Student Age"]> 1)
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 140     True
# 141    False
# 142    False
# 143     True
# 144    False
# Name: Student Age, Length: 145, dtype: bool

# %%
print(student_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 33 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   STUDENT ID                                                         145 non-null    object
#  1   Student Age                                                        145 non-null    int64
#  2   Sex                                                                145 non-null    int64
#  3   Graduated high-school type                                         145 non-null    int64
#  4   Scholarship type                                                   145 non-null    int64
#  5   Additional work                                                    145 non-null    int64
#  6   Regular artistic or sports activity                                145 non-null    int64
# ...

# %%
product_catalog = pd.DataFrame({
    "product_id": (101,103,204),
    "product_name": ("laptop","smartphone","tablet"),
    "price": (100,400,500)


})
print(product_catalog)
# Out:
#    product_id product_name  price
# 0         101       laptop    100
# 1         103   smartphone    400
# 2         204       tablet    500

# %%
print(product_catalog.loc[0,"price"])
# Out:
# 100

# %%
product1 = pd.DataFrame({
    "discount" : ["10%", "20%", "5%"],
    "tax" : ["10","20","30"]
})
print(product1)
# Out:
#   discount tax
# 0      10%  10
# 1      20%  20
# 2       5%  30

# %%
print(pd.concat([product_catalog,product1] , ignore_index=True))
# Out:
#    product_id product_name  price discount  tax
# 0       101.0       laptop  100.0      NaN  NaN
# 1       103.0   smartphone  400.0      NaN  NaN
# 2       204.0       tablet  500.0      NaN  NaN
# 3         NaN          NaN    NaN      10%   10
# 4         NaN          NaN    NaN      20%   20
# 5         NaN          NaN    NaN       5%   30
