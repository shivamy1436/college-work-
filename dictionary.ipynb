# %%
users = {
    "username": "shivam",
    "age":  19,
    "is_admin": True
}
print(users)
# Out:
# {'username': 'shivam', 'age': 19, 'is_admin': True}

# %%
print(users.get("username"));print(users.get("age"));print(users.get("is_admin"))
# Out:
# shivam
# 19
# True

# %%
users.pop("is_admin")
print(users)
# Out:
# {'username': 'shivam', 'age': 19}

# %%
users.update({"is_admin" : True}) #add key
print(users)
# Out:
# {'username': 'shivam', 'age': 19, 'is_admin': True}

# %%
del users["is_admin"]
print(users)
# Out:
# {'username': 'shivam', 'age': 19}

# %%
users = {
    "username": "shivam",
    "age":  19,
    "is_admin": True
}
print(users)
# Out:
# {'username': 'shivam', 'age': 19, 'is_admin': True}

# %%
del users["is_admin"]
print(users)
# Out:
# {'username': 'shivam', 'age': 19}

# %%
for x in users:
    print(users[x])
# Out:
# shivam
# 19

# %%
for x in users:
    print(x)
# Out:
# username
# age

# %%
import numpy

# %%
arr = numpy.array([1,2,3])
print(arr)
# Out:
# [1 2 3]
