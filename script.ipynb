# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([1,3,4,5,6])

# %%
y = x**2

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
uniform_dis = np.random.uniform(10,20,2)
normal_dis = np.random.normal(5,5,3)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.pie(uniform_dis)
plt.pie(normal_dis)
plt.title("shivam")
#plt.xlabel("x")
#plt.xlabel("y")
#plt.plot(x,label = "shivam")
plt.grid(True)
plt.legend()
plt.savefig("my_saved_file")

plt.show()
# Out:
# /var/folders/63/psmmrjnn7754t1142dq1phcr0000gn/T/ipykernel_7339/4041916306.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.plot(normal_dis)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 6
#       4 plt.xlabel("x")
#       5 plt.xlabel("y")
# ----> 6 plt.bar(x,label = "shivam")
#       7 plt.grid(True)
#       8 plt.legend()
#
# TypeError: bar() missing 1 required positional argument: 'height'
