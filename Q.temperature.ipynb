# %%
import numpy as np

# %%
data = np.array([23.3,23,56,44,34 ,23,48,11,56,34,14,35,67,89,12,43,23,32,54,65,76,56,33,32,32,54,64,34,21,20,19])
length2 = len(data)
print(length2)
# Out:
# 31

# %%
week = data[:8]
print(week)
# Out:
# [23.3 23.  56.  44.  34.  48. ]

# %%
week2 = data[8:15]
week3 = data[15:23]
week4 = data[22:31]
print(week2)
print(week3)
print(week4)
# Out:
# [56. 34. 14. 35. 67. 89. 12.]
# [43. 23. 32. 54. 65. 76. 56. 33.]
# [33. 32. 32. 54. 64. 34. 21. 20. 19.]

# %%
hot_days = data[data > 30]
print(hot_days)
# Out:
# [56. 44. 34. 48. 56. 34. 35. 67. 89. 43. 32. 54. 65. 76. 56. 33. 32. 32.
#  54. 64. 34.]

# %%
cold_day = data[data < 30]
print(cold_day)
# Out:
# [23.3 23.  23.  11.  14.  12.  23.  21.  20.  19. ]

# %%
length1 = len(hot_days)
print(length1)
# Out:
# 21

# %%
length3 = len(cold_day)
print(length3)
# Out:
# 10

# %%
percentage_hotdays = (length1/length2)*(100)
print(percentage_hotdays)
# Out:
# 67.74193548387096

# %%
percentage_colddays = (length3/length2)*(100)
print(percentage_colddays)
# Out:
# 32.25806451612903
